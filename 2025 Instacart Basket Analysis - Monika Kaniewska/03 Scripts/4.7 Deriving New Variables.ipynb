# %% [markdown]
# #### 01. Importing Libraries

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### 02. Importing Dataframes

# %%
# path
path = r'C:\Users\monik\Desktop\Career Foundry\Course\Data Immersion\4 Python\07.2025 Instacart Basket Analysis - Monika Kaniewska'

# %%
# Import ords_prods_merge dataframe
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))

# %% [markdown]
# #### 03. Checking dimensions

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  purchase_sequence  orders_day_of_week  \
# 0   2539329        1                  1                   2
# 1   2539329        1                  1                   2
# 2   2539329        1                  1                   2
# 3   2539329        1                  1                   2
# 4   2539329        1                  1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered                             product_name  aisle_id  \
# 0          0                                     Soda        77
# ...

# %%
ords_prods_merge.shape
# Out:
# (32404859, 14)

# %% [markdown]
# #### 04. Creating subset data

# %%
# Creating subset dataset
df = ords_prods_merge[:1000000]

# %%
df.head()
# Out:
#    order_id  user_id  purchase_sequence  orders_day_of_week  \
# 0   2539329        1                  1                   2
# 1   2539329        1                  1                   2
# 2   2539329        1                  1                   2
# 3   2539329        1                  1                   2
# 4   2539329        1                  1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered                             product_name  aisle_id  \
# 0          0                                     Soda        77
# ...

# %%
df.shape
# Out:
# (1000000, 14)

# %%
df.describe()
# Out:
#            order_id         user_id  purchase_sequence  orders_day_of_week  \
# count  1.000000e+06  1000000.000000     1000000.000000      1000000.000000
# mean   1.712098e+06     3295.070459          17.313612            2.765702
# std    9.870102e+05     1866.882221          17.931306            2.091348
# min    8.000000e+00        1.000000           1.000000            0.000000
# 25%    8.620670e+05     1699.000000           5.000000            1.000000
# 50%    1.711365e+06     3350.000000          11.000000            3.000000
# 75%    2.563843e+06     4937.000000          24.000000            5.000000
# max    3.420853e+06     6474.000000          99.000000            6.000000
#
#        order_hour_of_day  days_since_prior_order      product_id  \
# count     1000000.000000           936384.000000  1000000.000000
# mean           13.416690               11.062006    25595.891283
# std             4.221497                8.811708    14077.246950
# ...

# %% [markdown]
# #### 05. Defining function

# %%
# Defining price_label function
def price_label (row):
    if row['prices'] <= 5:
        return 'Low-range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid-range product'
    elif row['prices']> 15:
        return 'High-range product'
    else: return 'Not enough data'

# %%
# Applying price_label function
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\monik\AppData\Local\Temp\ipykernel_8952\1652086353.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product     673183
# Low-range product     314392
# High-range product     12425
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 99999.0

# %% [markdown]
# Comment for Bashir.
# In the exercise it says "Notice that you don’t have any rows with the “High-range product” label. This means there aren’t any products within the dataframe greater than $15." But in my example here I do have columns with "High-range product" - does this mean I did something wrong before when merging my datasets? Could you please point out where and when I made something wrong?

# %%
# checking for which product the price is 99999 - there must be a problem in here, since it is not very likely that a grocery product will have that high price.
df[df['prices'] == 99999.0]
# Out:
#         order_id  user_id  purchase_sequence  orders_day_of_week  \
# 128911    183964      873                  3                   0
# 128924   1851256      873                  4                   6
# 284218   1915696     1893                  1                   5
# 284229   2763293     1893                  2                   4
# 284252   2564805     1893                  4                   1
# 499076    949012     3339                  1                   1
# 499119    420057     3339                  2                   0
# 499141   1511997     3339                  3                   1
# 499158   1153448     3339                  4                   4
# 499180   2669259     3339                  5                   4
# 527458    965345     3531                 27                   2
# 767471   2291230     5034                  6                   1
# 767485   2324832     5034                  7                   6
# ...

# %% [markdown]
# #### 04. If-Statements with the loc() Function

# %%
# Defining location

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\monik\AppData\Local\Temp\ipykernel_8952\1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# Values count
df['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     673183
# Low-range product     314392
# High-range product     12425
# Name: count, dtype: int64

# %% [markdown]
# #### 05. IF statement with the loc() function on entire dataset

# %%
# Defining location

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# Value count
ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: count, dtype: int64

# %% [markdown]
# #### 06. If-Statements with For-Loops

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  purchase_sequence  orders_day_of_week  \
# 0   2539329        1                  1                   2
# 1   2539329        1                  1                   2
# 2   2539329        1                  1                   2
# 3   2539329        1                  1                   2
# 4   2539329        1                  1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered                             product_name  aisle_id  \
# 0          0                                     Soda        77
# ...

# %%
ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
# Busiest Day
result = []

for value in ords_prods_merge['orders_day_of_week']:
    if value ==0:
        result.append('Busiest day')
    elif value ==4:
        result.append('Least busy')
    else:
        result.append('Regular busy')

# %%
ords_prods_merge['Busiest_day'] = result

# %%
ords_prods_merge['Busiest_day'].value_counts(dropna = False)
# Out:
# Busiest_day
# Regular busy    22416875
# Busiest day      6204182
# Least busy       3783802
# Name: count, dtype: int64

# %%
ords_prods_merge.drop(columns=['Busiest_day'], inplace=True)

# %% [markdown]
# #### 07. Task

# %%
# Changing busiest day to businest days

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  purchase_sequence  orders_day_of_week  \
# 0   2539329        1                  1                   2
# 1   2539329        1                  1                   2
# 2   2539329        1                  1                   2
# 3   2539329        1                  1                   2
# 4   2539329        1                  1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered                             product_name  aisle_id  \
# 0          0                                     Soda        77
# ...

# %%
ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
# Busiest Days
result = []

for value in ords_prods_merge['orders_day_of_week']:
    if value in [0, 1]:
        result.append('Busiest days')
    elif value in [3, 4]:
        result.append('Least busy days')
    else:
        result.append('Regular busy')

# %%
# Check the values of this new column for accuracy. Note any observations in markdown format.

# %%
ords_prods_merge['Busiest_days'] = result

# %%
ords_prods_merge['Busiest_days'].value_counts(dropna = False)
# Out:
# Busiest_days
# Regular busy       12916111
# Busiest days       11864412
# Least busy days     7624336
# Name: count, dtype: int64

# %% [markdown]
# All values have been allocated.

# %%
# The busiest hours of the day.  Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  purchase_sequence  orders_day_of_week  \
# 0   2539329        1                  1                   2
# 1   2539329        1                  1                   2
# 2   2539329        1                  1                   2
# 3   2539329        1                  1                   2
# 4   2539329        1                  1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered                             product_name  aisle_id  \
# 0          0                                     Soda        77
# ...

# %%
ords_prods_merge['order_hour_of_day'].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
result = []

for value in ords_prods_merge['order_hour_of_day']:
  if value in [10, 11, 14, 15, 13, 12, 16]:
    result.append('Most orders')
  elif value in [3,4,2,5,1,0]:
    result.append('Fewest orders')
  else:
    result.append('Average orders')

# %%
ords_prods_merge['busiest_period_of_day'] = result

# %%
# Print the frequency for this new column.
ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most orders       18663868
# Average orders    13144663
# Fewest orders       596328
# Name: count, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  purchase_sequence  orders_day_of_week  \
# 0   2539329        1                  1                   2
# 1   2539329        1                  1                   2
# 2   2539329        1                  1                   2
# 3   2539329        1                  1                   2
# 4   2539329        1                  1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered                             product_name  aisle_id  \
# 0          0                                     Soda        77
# ...

# %%
# Export your dataframe as a pickle file
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merge_extra_columns.pkl'))
